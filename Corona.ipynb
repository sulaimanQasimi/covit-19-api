# %% [markdown]
# <a href="https://colab.research.google.com/github/sulaimanQasimi/covit-19-api/blob/main/Corona.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install uk-covid19
# Out:
# Collecting uk-covid19
#   Downloading uk_covid19-1.2.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from uk-covid19) (2021.10.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from uk-covid19) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->uk-covid19) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->uk-covid19) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->uk-covid19) (2.10)
# Installing collected packages: uk-covid19
# Successfully installed uk-covid19-1.2.2

# %%
from uk_covid19 import Cov19API

# %%
england_only = [
    'areaType=nation',
    'areaName=England'
]

# %%
cases_and_deaths = {
    "date": "date",
    "areaName": "areaName",
    "areaCode": "areaCode",
    "newCasesByPublishDate": "newCasesByPublishDate",
    "cumCasesByPublishDate": "cumCasesByPublishDate",
    "newDeaths28DaysByDeathDate": "newDeaths28DaysByDeathDate",
    "cumDeaths28DaysByDeathDate": "cumDeaths28DaysByDeathDate"
}

# %%
api = Cov19API(filters=england_only, structure=cases_and_deaths)

# %%
data = api.get_json()

print(data)
# Out:
# {'data': [{'date': '2022-01-06', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 152306, 'cumCasesByPublishDate': 11858941, 'newDeaths28DaysByDeathDate': None, 'cumDeaths28DaysByDeathDate': None}, {'date': '2022-01-05', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 150232, 'cumCasesByPublishDate': 11706635, 'newDeaths28DaysByDeathDate': 42, 'cumDeaths28DaysByDeathDate': 130018}, {'date': '2022-01-04', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 148725, 'cumCasesByPublishDate': 11557285, 'newDeaths28DaysByDeathDate': 97, 'cumDeaths28DaysByDeathDate': 129976}, {'date': '2022-01-03', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 137541, 'cumCasesByPublishDate': 11408560, 'newDeaths28DaysByDeathDate': 101, 'cumDeaths28DaysByDeathDate': 129879}, {'date': '2022-01-02', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 123547, 'cumCasesByPublishDate': 11272332, 'newDeaths28DaysByDeathDate': 99, 'cumDeaths28DaysByDeathDate': 129778}, {'date': '2022-01-01', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 162572, 'cumCasesByPublishDate': 11151423, 'newDeaths28DaysByDeathDate': 108, 'cumDeaths28DaysByDeathDate': 129679}, {'date': '2021-12-31', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 160276, 'cumCasesByPublishDate': 10988851, 'newDeaths28DaysByDeathDate': 102, 'cumDeaths28DaysByDeathDate': 129571}, {'date': '2021-12-30', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 146604, 'cumCasesByPublishDate': 10828575, 'newDeaths28DaysByDeathDate': 146, 'cumDeaths28DaysByDeathDate': 129469}, {'date': '2021-12-29', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 138287, 'cumCasesByPublishDate': 10683026, 'newDeaths28DaysByDeathDate': 87, 'cumDeaths28DaysByDeathDate': 129323}, {'date': '2021-12-28', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 117093, 'cumCasesByPublishDate': 10545584, 'newDeaths28DaysByDeathDate': 127, 'cumDeaths28DaysByDeathDate': 129236}, {'date': '2021-12-27', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 98515, 'cumCasesByPublishDate': 10429274, 'newDeaths28DaysByDeathDate': 106, 'cumDeaths28DaysByDeathDate': 129109}, {'date': '2021-12-26', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 103558, 'cumCasesByPublishDate': 10332128, 'newDeaths28DaysByDeathDate': 96, 'cumDeaths28DaysByDeathDate': 129003}, {'date': '2021-12-25', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 113628, 'cumCasesByPublishDate': 10229538, 'newDeaths28DaysByDeathDate': 83, 'cumDeaths28DaysByDeathDate': 128907}, {'date': '2021-12-24', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 105069, 'cumCasesByPublishDate': 10115910, 'newDeaths28DaysByDeathDate': 102, 'cumDeaths28DaysByDeathDate': 128824}, {'date': '2021-12-23', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 107055, 'cumCasesByPublishDate': 10011650, 'newDeaths28DaysByDeathDate': 111, 'cumDeaths28DaysByDeathDate': 128722}, {'date': '2021-12-22', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 95795, 'cumCasesByPublishDate': 9905451, 'newDeaths28DaysByDeathDate': 108, 'cumDeaths28DaysByDeathDate': 128611}, {'date': '2021-12-21', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 80916, 'cumCasesByPublishDate': 9810446, 'newDeaths28DaysByDeathDate': 81, 'cumDeaths28DaysByDeathDate': 128503}, {'date': '2021-12-20', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 76065, 'cumCasesByPublishDate': 9731126, 'newDeaths28DaysByDeathDate': 98, 'cumDeaths28DaysByDeathDate': 128422}, {'date': '2021-12-19', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 71702, 'cumCasesByPublishDate': 9655061, 'newDeaths28DaysByDeathDate': 85, ' ...
